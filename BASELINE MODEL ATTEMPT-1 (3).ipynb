# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # MATCHUP DATA REGULAR SEASON 2011-12 (Seperate Team Approach)

# %%
data_2011_12 = pd.read_csv(r"C:\NHL DATA\FINAL MODEL FEEDING DATASET NORMALIZATION METHOD AND SEPERATE REPRESENTATION\FINAL_2011_12_MODEL_FEEDING_DATASET_ATTEMPTED_BY_NORMALIZATON_METHOD_WITH_SEPERATE_TEAM_STATS_REPRESENTATION.csv")
data_2011_12.drop(["Unnamed: 0","E+/-.1","E+/-"],axis = 1, inplace  = True)
data_2011_12 = data_2011_12.loc[~data_2011_12.index.duplicated(keep='first')]
((data_2011_12)).shape
# Out:
# (1230, 155)

# %% [markdown]
# # MATCHUP DATA REGULAR SEASON 2012-13 (Seperate Team Approach)

# %%
data_2012_13 = pd.read_csv(r"C:\NHL DATA\FINAL MODEL FEEDING DATASET NORMALIZATION METHOD AND SEPERATE REPRESENTATION\FINAL_2012_13_MODEL_FEEDING_DATASET_ATTEMPTED_BY_NORMALIZATON_METHOD_WITH_SEPERATE_TEAM_STATS_REPRESENTATION.csv")
data_2012_13.drop(["Unnamed: 0"],axis = 1, inplace  = True)
data_2012_13 = data_2012_13.loc[~data_2012_13.index.duplicated(keep='first')]
(data_2012_13).shape
# Out:
# (720, 155)

# %% [markdown]
# # MATCHUP DATA REGULAR SEASON 2013-14 (Seperate Team Approach)

# %%
data_2013_14 = pd.read_csv(r"C:\NHL DATA\FINAL MODEL FEEDING DATASET NORMALIZATION METHOD AND SEPERATE REPRESENTATION\FINAL_2013_14_MODEL_FEEDING_DATASET_ATTEMPTED_BY_NORMALIZATON_METHOD_WITH_SEPERATE_TEAM_STATS_REPRESENTATION.csv")
data_2013_14.drop(["Unnamed: 0","E+/-.1","E+/-"],axis = 1, inplace  = True)
data_2013_14 = data_2013_14.loc[~data_2013_14.index.duplicated(keep='first')]
(data_2013_14).shape
# Out:
# (1231, 155)

# %% [markdown]
# # MATCHUP DATA REGULAR SEASON 2014-15 (Seperate Team Approach)

# %%
data_2014_15 = pd.read_csv(r"C:\NHL DATA\FINAL MODEL FEEDING DATASET NORMALIZATION METHOD AND SEPERATE REPRESENTATION\FINAL_2014_15_MODEL_FEEDING_DATASET_ATTEMPTED_BY_NORMALIZATON_METHOD_WITH_SEPERATE_TEAM_STATS_REPRESENTATION.csv")
data_2014_15.drop(["Unnamed: 0","E+/-.1","E+/-"],axis = 1, inplace  = True)
data_2014_15 = data_2014_15.loc[~data_2014_15.index.duplicated(keep='first')]
data_2014_15.shape
# Out:
# (1230, 155)

# %% [markdown]
# # MATCHUP DATA REGULAR SEASON 2015-16 (Seperate Team Approach)

# %%
data_2015_16 = pd.read_csv(r"C:\NHL DATA\FINAL MODEL FEEDING DATASET NORMALIZATION METHOD AND SEPERATE REPRESENTATION\FINAL_2015_16_MODEL_FEEDING_DATASET_ATTEMPTED_BY_NORMALIZATON_METHOD_WITH_SEPERATE_TEAM_STATS_REPRESENTATION.csv")
data_2015_16.drop(["Unnamed: 0","E+/-.1","E+/-"],axis = 1, inplace  = True)
data_2015_16 = data_2015_16.loc[~data_2016_17.index.duplicated(keep='first')]
data_2015_16.shape
# Out:
# (1230, 155)

# %% [markdown]
# # MATCHUP DATA REGULAR SEASON 2016-17 (Seperate Team Approach)

# %%
data_2016_17 = pd.read_csv(r"C:\NHL DATA\FINAL MODEL FEEDING DATASET NORMALIZATION METHOD AND SEPERATE REPRESENTATION\FINAL_2016_17_MODEL_FEEDING_DATASET_ATTEMPTED_BY_NORMALIZATON_METHOD_WITH_SEPERATE_TEAM_STATS_REPRESENTATION.csv")
data_2016_17.drop(["Unnamed: 0"],axis = 1, inplace  = True)
data_2016_17 = data_2016_17.loc[~data_2016_17.index.duplicated(keep='first')]
data_2016_17.
# Out:
#                     Visitor  G                 Home  G.1  Total_goal  \
# 0           St. Louis Blues  5   Chicago Blackhawks    2           7
# 1            Calgary Flames  4      Edmonton Oilers    7          11
# 2       Toronto Maple Leafs  4      Ottawa Senators    5           9
# 3         Los Angeles Kings  1      San Jose Sharks    2           3
# 4        Montreal Canadiens  4       Buffalo Sabres    1           5
# ...                     ... ..                  ...  ...         ...
# 1225    Carolina Hurricanes  4  Philadelphia Flyers    3           7
# 1226     Colorado Avalanche  2      St. Louis Blues    3           5
# 1227         Buffalo Sabres  2  Tampa Bay Lightning    4           6
# 1228  Columbus Blue Jackets  3  Toronto Maple Leafs    2           5
# 1229       Florida Panthers  2  Washington Capitals    0           2
#
#             Rk     AvAge   GP         W         L  ...  FF rel.1   oiSH%.1  \
# 0     0.310345  0.542857  0.0  0.727273  0.270270  ...  0.648012  0.418451
# 1     0.482759  0.628571  0.0  0.696970  0.378378  ...  0.688513  0.357430
# 2     0.413793  0.028571  0.0  0.545455  0.216216  ...  0.376196  0.038210
# 3     0.724138  0.857143  0.0  0.515152  0.432432  ...  0.621168  0.337614
# 4     0.206897  0.771429  0.0  0.757576  0.189189  ...  0.932914  0.131366
# ...        ...       ...  ...       ...       ...  ...       ...       ...
# 1225  0.689655  0.200000  0.0  0.424242  0.324324  ...  0.911241  0.230883
# 1226  1.000000  0.428571  0.0  0.000000  1.000000  ...  1.000000  0.596099
# 1227  0.862069  0.085714  0.0  0.333333  0.486486  ...  0.725417  0.204881
# 1228  0.103448  0.028571  0.0  0.848485  0.135135  ...  0.859397  0.451573
# 1229  0.758621  0.714286  0.0  0.393939  0.459459  ...  0.649633  0.296505
#
#        oiSV%.1     PDO.1    oZS%.1    dZS%.1      TK.1      GV.1    SAtt.1  \
# 0     0.761743  0.701217  0.743034  0.256966  0.578739  0.608151  0.631876
# 1     0.580598  0.546077  0.609423  0.390577  0.535869  0.762954  0.518444
# 2     0.212532  0.065924  0.572698  0.427302  0.259309  0.414661  0.262481
# 3     0.637859  0.561310  0.771070  0.229261  0.609841  1.000000  0.628236
# 4     0.627479  0.386189  0.452114  0.547886  0.084526  0.157371  0.091568
# ...        ...       ...       ...       ...       ...       ...       ...
# 1225  0.213780  0.223658  0.633778  0.366222  0.129183  0.389682  0.503136
# 1226  0.276371  0.562204  0.303011  0.696989  0.311979  0.000000  0.282034
# 1227  0.393230  0.307816  0.289781  0.710219  0.212355  0.344555  0.308903
# 1228  0.343012  0.484157  0.232401  0.767599  1.000000  0.799181  1.000000
# 1229  1.000000  0.739125  0.649123  0.350877  0.577443  0.676012  0.559786
#
#        Thru%.1
# 0     0.701873
# 1     0.567291
# 2     0.760300
# 3     0.435148
# 4     0.897907
# ...        ...
# 1225  0.731327
# 1226  0.807407
# 1227  0.409497
# 1228  0.488185
# 1229  0.553090
#
# [1230 rows x 155 columns]

# %% [markdown]
# # MATCHUP DATA REGULAR SEASON 2017-18 (Seperate Team Approach)

# %%
data_2017_18 = pd.read_csv(r"C:\NHL DATA\FINAL MODEL FEEDING DATASET NORMALIZATION METHOD AND SEPERATE REPRESENTATION\FINAL_2017_18_MODEL_FEEDING_DATASET_ATTEMPTED_BY_NORMALIZATON_METHOD_WITH_SEPERATE_TEAM_STATS_REPRESENTATION.csv")
# data_2017_18.columns = data_2017_18.loc[0].to_list()
# data_2017_18.drop([0],axis = 0,inplace = True)
data_2017_18.drop(["Unnamed: 0","E+/-.1","E+/-"],axis = 1, inplace  = True)
data_2017_18 = data_2017_18.loc[~data_2017_18.index.duplicated(keep='first')]
data_2017_18
for i in range(0,(data_2017_18.shape[0])) :
    if data_2017_18.iloc[i, ].isnull().sum() > 0 :
        count = count + 1
        print(f'Number of null values in row {i} : ' + str(data_2017_18.iloc[i, ].isnull().sum()))
count
# Out:
# Number of null values in row 14 : 44
# Number of null values in row 20 : 44
# Number of null values in row 36 : 44
# Number of null values in row 55 : 44
# Number of null values in row 73 : 44
# Number of null values in row 79 : 44
# Number of null values in row 82 : 44
# Number of null values in row 96 : 44
# Number of null values in row 118 : 44
# Number of null values in row 125 : 44
# Number of null values in row 145 : 44
# Number of null values in row 164 : 44
# Number of null values in row 170 : 44
# Number of null values in row 194 : 44
# Number of null values in row 209 : 44
# Number of null values in row 232 : 44
# Number of null values in row 236 : 44
# Number of null values in row 260 : 44
# Number of null values in row 285 : 44
# Number of null values in row 300 : 44
# Number of null values in row 331 : 44
# Number of null values in row 346 : 44
# Number of null values in row 354 : 44
# Number of null values in row 366 : 44
# Number of null values in row 376 : 44
# Number of null values in row 404 : 44
# Number of null values in row 422 : 44
# Number of null values in row 436 : 44
# Number of null values in row 454 : 44
# Number of null values in row 471 : 44
# Number of null values in row 478 : 44
# Number of null values in row 499 : 44
# Number of null values in row 524 : 44
# Number of null values in row 537 : 44
# Number of null values in row 554 : 44
# Number of null values in row 572 : 44
# Number of null values in row 584 : 44
# Number of null values in row 593 : 44
# Number of null values in row 610 : 44
# Number of null values in row 621 : 44
# Number of null values in row 637 : 44
# Number of null values in row 642 : 44
# Number of null values in row 656 : 44
# Number of null values in row 661 : 44
# Number of null values in row 702 : 44
# Number of null values in row 712 : 44
# Number of null values in row 726 : 44
# Number of null values in row 736 : 44
# Number of null values in row 753 : 44
# Number of null values in row 770 : 44
# Number of null values in row 778 : 44
# Number of null values in row 801 : 44
# Number of null values in row 807 : 44
# Number of null values in row 832 : 44
# Number of null values in row 848 : 44
# Number of null values in row 861 : 44
# Number of null values in row 863 : 44
# Number of null values in row 886 : 44
# Number of null values in row 900 : 44
# Number of null values in row 924 : 44
# Number of null values in row 936 : 44
# Number of null values in row 951 : 44
# Number of null values in row 966 : 44
# Number of null values in row 979 : 44
# Number of null values in row 983 : 44
# Number of null values in row 1004 : 44
# Number of null values in row 1026 : 44
# Number of null values in row 1041 : 44
# Number of null values in row 1055 : 44
# Number of null values in row 1075 : 44
# Number of null values in row 1103 : 44
# Number of null values in row 1111 : 44
# Number of null values in row 1126 : 44
# Number of null values in row 1140 : 44
# Number of null values in row 1155 : 44
# Number of null values in row 1172 : 44
# Number of null values in row 1188 : 44
# Number of null values in row 1201 : 44
# Number of null values in row 1220 : 44
# Number of null values in row 1234 : 44
# Number of null values in row 1254 : 44
# Number of null values in row 1257 : 44
# 249

# %% [markdown]
# # MATCHUP DATA REGULAR SEASON 2018-19 (Seperate Team Approach)

# %%
data_2018_19 = pd.read_csv(r'C:\NHL DATA\FINAL MODEL FEEDING DATASET NORMALIZATION METHOD AND SEPERATE REPRESENTATION\FINAL_2018_19_MODEL_FEEDING_DATASET_ATTEMPTED_BY_NORMALIZATON_METHOD_WITH_SEPERATE_TEAM_STATS_REPRESENTATION.csv')
data_2018_19.drop(['Unnamed: 0',"E+/-.1","E+/-"],axis = 1,inplace = True)
#data_2018_19.columns = data_2018_19.loc[0].to_list()
#data_2018_19.drop([0],axis = 0,inplace = True)
#data_2018_19.drop(['Date','Visitor','Home',"Att."],axis = 1,inplace = True)
#data_2018_19.reset_index(inplace=True, drop=True)
#data_2018_19 = data_2018_19.loc[~data_2018_19.index.duplicated(keep='first')]
#data_2018_19.columns = data_2017_18.columns
(data_2018_19.columns) = (data_2017_18.columns)
data_2018_19
# Out:
#                   Visitor  G                 Home  G.1  Total_goal        Rk  \
# 0           Anaheim Ducks  5      San Jose Sharks    2           7  0.766667
# 1      Montreal Canadiens  2  Toronto Maple Leafs    3           5  0.433333
# 2          Calgary Flames  2    Vancouver Canucks    5           7  0.066667
# 3           Boston Bruins  0  Washington Capitals    7           7  0.033333
# 4           Boston Bruins  4       Buffalo Sabres    0           4  0.033333
# ...                   ... ..                  ...  ...         ...       ...
# 1266  Carolina Hurricanes  4  Philadelphia Flyers    3           7  0.333333
# 1267     New York Rangers  4  Pittsburgh Penguins    3           7  0.833333
# 1268   Colorado Avalanche  2      San Jose Sharks    5           7  0.533333
# 1269    Vancouver Canucks  2      St. Louis Blues    3           5  0.733333
# 1270   New York Islanders  3  Washington Capitals    0           3  0.133333
#
#          AvAge   GP         W         L  ...  FF rel.1   oiSH%.1   oiSV%.1  \
# 0     0.310345  0.0  0.181818  0.677419  ...  0.716725  0.679754  0.248781
# 1     0.448276  0.0  0.454545  0.451613  ...  0.697593  0.792777  0.524378
# 2     0.379310  0.0  0.636364  0.290323  ...  0.988865  0.467193  0.327294
# 3     0.724138  0.0  0.606061  0.258065  ...  1.000000  1.000000  0.824487
# 4     0.724138  0.0  0.606061  0.258065  ...  0.651036  0.000000  0.515349
# ...        ...  ...       ...       ...  ...       ...       ...       ...
# 1266  0.068966  0.0  0.515152  0.419355  ...  0.713628  0.368741  0.481631
# 1267  0.275862  0.0  0.090909  0.645161  ...  0.575187  0.607492  0.967424
# 1268  0.137931  0.0  0.272727  0.451613  ...  0.716725  0.679754  0.248781
# 1269  0.103448  0.0  0.181818  0.645161  ...  0.106873  0.410294  0.422540
# 1270  0.620690  0.0  0.575758  0.354839  ...  1.000000  1.000000  0.824487
#
#          PDO.1    oZS%.1    dZS%.1      TK.1      GV.1    SAtt.1   Thru%.1
# 0     0.368265  0.726208  0.273792  0.793621  0.724174  0.857126  0.154432
# 1     0.642380  0.458791  0.541209  0.728637  1.000000  1.000000  0.033504
# 2     0.281476  0.489445  0.510827  0.186545  0.116602  0.293603  0.725007
# 3     1.000000  0.477480  0.522520  0.714577  0.933647  0.754261  0.221158
# 4     0.089995  0.484569  0.515694  0.181665  0.393787  0.433949  0.590740
# ...        ...       ...       ...       ...       ...       ...       ...
# 1266  0.321108  0.201544  0.798456  0.217936  0.566342  0.544886  0.699104
# 1267  0.825514  0.381542  0.618458  0.533583  0.724505  0.701527  0.641165
# 1268  0.368265  0.726208  0.273792  0.793621  0.724174  0.857126  0.154432
# 1269  0.251640  0.648142  0.351858  0.481335  0.190121  0.475975  0.489650
# 1270  1.000000  0.477480  0.522520  0.714577  0.933647  0.754261  0.221158
#
# [1271 rows x 155 columns]

# %% [markdown]
# # MATCHUP DATA REGULAR SEASON 2019-20 (Seperate Team Approach)

# %%
data_2019_20 = pd.read_csv(r"C:\NHL DATA\FINAL MODEL FEEDING DATASET NORMALIZATION METHOD AND SEPERATE REPRESENTATION\FINAL_2019_20_MODEL_FEEDING_DATASET_ATTEMPTED_BY_NORMALIZATON_METHOD_WITH_SEPERATE_TEAM_STATS_REPRESENTATION.csv")
data_2019_20.drop(["Unnamed: 0","E+/-.1","E+/-"],axis = 1, inplace  = True)
#data_2019_20 = data_2019_20.loc[~data_2019_20.index.duplicated(keep='first')]
data_2019_20.shape
# Out:
# (1084, 155)

# %% [markdown]
# # MATCHUP DATA REGULAR SEASON 2020-21 (Seperate Team Approach)

# %%
data_2020_21 = pd.read_csv(r"C:\NHL DATA\FINAL MODEL FEEDING DATASET NORMALIZATION METHOD AND SEPERATE REPRESENTATION\FINAL_2020_21_MODEL_FEEDING_DATASET_ATTEMPTED_BY_NORMALIZATON_METHOD_WITH_SEPERATE_TEAM_STATS_REPRESENTATION.csv")
data_2020_21.drop(["Unnamed: 0","E+/-.1","E+/-"],axis = 1, inplace  = True) 
data_2020_21 = data_2020_21.loc[~data_2020_21.index.duplicated(keep='first')]
data_2020_21.columns
# Out:
#                  Visitor  G                 Home  G.1  Total_goal        Rk  \
# 0        St. Louis Blues  4   Colorado Avalanche    1           5  0.433333
# 1      Vancouver Canucks  5      Edmonton Oilers    3           8  0.766667
# 2    Pittsburgh Penguins  3  Philadelphia Flyers    6           9  0.200000
# 3     Chicago Blackhawks  1  Tampa Bay Lightning    5           6  0.633333
# 4     Montreal Canadiens  4  Toronto Maple Leafs    5           9  0.566667
# ..                   ... ..                  ...  ...         ...       ...
# 863  Toronto Maple Leafs  2        Winnipeg Jets    4           6  0.166667
# 864    Vancouver Canucks  4      Edmonton Oilers    1           5  0.766667
# 865       Calgary Flames  6    Vancouver Canucks    5          11  0.666667
# 866       Calgary Flames  2    Vancouver Canucks    4           6  0.666667
# 867    Vancouver Canucks  2       Calgary Flames    6           8  0.766667
#
#         AvAge   GP     W         L  ...  FF rel.1   oiSH%.1   oiSV%.1  \
# 0    0.583333  0.0  0.48  0.363636  ...  0.534809  0.625306  0.930863
# 1    0.395833  0.0  0.32  0.772727  ...  0.525452  0.637194  0.726461
# 2    0.541667  0.0  0.88  0.181818  ...  0.000000  0.266957  0.371620
# 3    0.250000  0.0  0.36  0.590909  ...  0.387958  0.935465  0.590094
# 4    0.645833  0.0  0.36  0.409091  ...  0.860208  0.892788  1.000000
# ..        ...  ...   ...       ...  ...       ...       ...       ...
# 863  0.666667  0.0  0.80  0.090909  ...  0.298987  0.664976  0.835341
# 864  0.395833  0.0  0.32  0.772727  ...  0.525452  0.637194  0.726461
# 865  0.583333  0.0  0.44  0.681818  ...  0.303777  0.445450  0.350736
# 866  0.583333  0.0  0.44  0.681818  ...  0.303777  0.445450  0.350736
# 867  0.395833  0.0  0.32  0.772727  ...  0.521151  0.691666  0.823484
#
#         PDO.1    oZS%.1    dZS%.1      TK.1      GV.1    SAtt.1   Thru%.1
# 0    0.814940  0.741195  0.258805  0.523028  0.000000  0.573695  0.120278
# 1    0.643667  0.562660  0.437340  0.762519  0.710852  0.510289  0.426770
# 2    0.103244  0.639343  0.360657  0.326169  0.182679  0.303123  0.000000
# 3    0.709157  0.853471  0.146529  0.334645  0.025035  0.610627  0.516372
# 4    1.000000  0.632924  0.367076  0.872862  1.000000  0.611376  0.412591
# ..        ...       ...       ...       ...       ...       ...       ...
# 863  0.757064  0.515890  0.484110  0.716412  0.620746  0.654588  0.436519
# 864  0.643667  0.562660  0.437340  0.762519  0.710852  0.510289  0.426770
# 865  0.302779  0.400148  0.599852  0.569850  0.326175  0.120916  0.628573
# 866  0.302779  0.400148  0.599852  0.569850  0.326175  0.120916  0.628573
# 867  0.760725  0.885838  0.114162  0.802180  0.697619  0.462821  0.248514
#
# [868 rows x 155 columns]

# %% [markdown]
# # MATCHUP DATA REGULAR SEASON 2021-22 (Seperate Team Approach)

# %%
data_2021_22 = pd.read_csv(r"C:\NHL DATA\FINAL MODEL FEEDING DATASET NORMALIZATION METHOD AND SEPERATE REPRESENTATION\FINAL_2021_22_MODEL_FEEDING_DATASET_ATTEMPTED_BY_NORMALIZATON_METHOD_WITH_SEPERATE_TEAM_STATS_REPRESENTATION.csv")
data_2021_22.drop(["Unnamed: 0",'154','78'],axis = 1, inplace  = True) 
data_2021_22 = data_2021_22.loc[~data_2021_22.index.duplicated(keep='first')]
data_2021_22.columns = data_2020_21.columns
list(data_2021_22.columns)
# Out:
# ['Visitor',
#  'G',
#  'Home',
#  'G.1',
#  'Total_goal',
#  'Rk',
#  'AvAge',
#  'GP',
#  'W',
#  'L',
#  'OL',
#  'PTS',
#  'PTS%',
#  'GF',
#  'GA',
#  'SOW',
#  'SOL',
#  'SRS',
#  'SOS',
#  'GF/G',
#  'GF/G.1',
#  'PP',
#  'PPO',
#  'PP%',
#  'PPA',
#  'PPOA',
#  'PK%',
#  'SH',
#  'SHA',
#  'PIM/G',
#  'oPIM/G',
#  'S',
#  'S%',
#  'SA',
#  'SV%',
#  'SO',
#  'Rk.1',
#  'Age',
#  'GP.1',
#  'G.1.1',
#  'A',
#  'PTS.1',
#  '+/-',
#  'PIM',
#  'PS',
#  'EV',
#  'PP.1',
#  'SH.1',
#  'GW',
#  'Assist-EV',
#  'PP.2',
#  'Assist-SH',
#  'S.1',
#  'S%.1',
#  'TOI',
#  'BLK',
#  'HIT',
#  'FOW',
#  'FOL',
#  'FO%',
#  'Rk.2',
#  'Age.1',
#  'GP.2',
#  'CF',
#  'CA',
#  'CF%',
#  'CF% rel',
#  'FF',
#  'FA',
#  'FF%',
#  'FF rel',
#  'oiSH%',
#  'oiSV%',
#  'PDO',
#  'oZS%',
#  'dZS%',
#  'TK',
#  'GV',
#  'SAtt',
#  'Thru%',
#  'Rk.1.1',
#  'AvAge.1',
#  'GP.1.1',
#  'W.1',
#  'L.1',
#  'OL.1',
#  'PTS.1.1',
#  'PTS%.1',
#  'GF.1',
#  'GA.1',
#  'SOW.1',
#  'SOL.1',
#  'SRS.1',
#  'SOS.1',
#  'GF/G.1.1',
#  'GF/G.1.2',
#  'PP.1.1',
#  'PPO.1',
#  'PP%.1',
#  'PPA.1',
#  'PPOA.1',
#  'PK%.1',
#  'SH.1.1',
#  'SHA.1',
#  'PIM/G.1',
#  'oPIM/G.1',
#  'S.1.1',
#  'S%.1.1',
#  'SA.1',
#  'SV%.1',
#  'SO.1',
#  'Rk.1.2',
#  'Age.1.1',
#  'GP.1.2',
#  'G.1.2',
#  'A.1',
#  'PTS.1.2',
#  '+/-.1',
#  'PIM.1',
#  'PS.1',
#  'EV.1',
#  'PP.1.2',
#  'SH.1.2',
#  'GW.1',
#  'Assist-EV.1',
#  'PP.1.3',
#  'Assist-SH.1',
#  'S.1.2',
#  'S%.1.2',
#  'TOI.1',
#  'BLK.1',
#  'HIT.1',
#  'FOW.1',
#  'FOL.1',
#  'FO%.1',
#  'Rk.1.3',
#  'Age.1.2',
#  'GP.1.3',
#  'CF.1',
#  'CA.1',
#  'CF%.1',
#  'CF% rel.1',
#  'FF.1',
#  'FA.1',
#  'FF%.1',
#  'FF rel.1',
#  'oiSH%.1',
#  'oiSV%.1',
#  'PDO.1',
#  'oZS%.1',
#  'dZS%.1',
#  'TK.1',
#  'GV.1',
#  'SAtt.1',
#  'Thru%.1']

# %% [markdown]
# # COMBINING DATASETS OF MATCHUPS OF DIFFERENT SEASONS

# %%
final_model_feeding_dataset = pd.concat([data_2020_21,data_2019_20,data_2014_15,data_2015_16,data_2016_17,data_2017_18,data_2018_19,data_2011_12,data_2012_13,data_2013_14], axis = 0, ignore_index = True)
#final_model_feeding_dataset = pd.concat([data_2020_21,data_2019_20,data_2018_19], axis = 0, ignore_index = True)

final_model_feeding_dataset.shape
#final_model_feeding_dataset = final_model_feeding_dataset.reset_index()
# Out:
# (11365, 155)

# %%
## Removing NAN values
count = 0
for i in range(0,(final_model_feeding_dataset.shape[0])) :
    if final_model_feeding_dataset.loc[i].isnull().sum() > 0 :
        count = count + 1
        final_model_feeding_dataset.drop([i],inplace = True, axis =0)
final_model_feeding_dataset = final_model_feeding_dataset.reset_index()
count
# Out:
# 171

# %%
x_train = final_model_feeding_dataset.drop(['index','Total_goal',"Visitor","Home","G","G.1"], axis = 1)
y_train = final_model_feeding_dataset['Total_goal']

x_test = data_2021_22.drop(['Total_goal',"Visitor","Home","G","G.1"], axis = 1)
y_test = data_2021_22["Total_goal"]
type(x_train)
# Out:
# pandas.core.frame.DataFrame

# %%
x_train.shape
# Out:
# (11194, 150)

# %%
final_model_feeding_dataset['Total_goal'].isnull().sum()
(y_test.isnull().sum())
# Out:
# 0

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
# y_train = y_train.to_numpy() 
# y_train.reshape(-1, 1)
# y_train = scaler.fit_transform(y_train)
x_train[0]
# Out:
# array([-1.7262049 , -1.7262049 , -0.23923085,  0.40611843, -0.34914727,
#        -0.17005553, -0.28267612,  0.57399233,  0.12545209,  0.12780387,
#         0.32328179,  0.59933788, -0.08927203,  0.33511057, -0.28954916,
#         0.00449566,  0.31025315,  0.57468084,  0.87860531, -0.16063337,
#         1.19162994,  1.1165771 ,  0.8592206 , -0.50497933,  1.04537009,
#        -1.18048778, -0.19902656, -0.63081149, -1.03472319,  0.5721461 ,
#         0.31217158, -0.30065243, -1.11014409,  1.13435173,  0.27229709,
#         0.20446322, -0.01608183,  0.24847097,  0.15629406, -0.14170103,
#        -0.04122741, -0.5027818 , -0.42951839,  0.57680367,  0.99913713,
#        -0.36843009, -0.25506739,  0.78185485,  0.93903644, -0.53780868,
#         1.12109841,  0.20663244,  0.23342968,  0.48356156,  0.62004288,
#        -0.13037677,  1.60287216,  1.01745404,  0.38779079, -0.51767306,
#        -1.19578806,  0.1897662 , -0.74765191, -0.08400844, -1.37798855,
#         0.18464894, -0.93875319,  0.02784591,  1.43452058, -0.30954466,
#         0.27967794, -0.10912475,  0.10928799,  0.29055976, -0.80441443,
#        -1.07741674, -0.51037425, -1.59281496, -0.7254964 , -0.34897915,
#         1.64494439, -1.53526202, -1.04911486,  1.77373481,  1.76585453,
#         1.96280571, -1.23884245, -1.62451673, -1.01932701,  1.63105977,
#        -1.76319026,  1.95220032, -1.24864033,  2.07944252,  2.29616367,
#         1.08117162, -0.17549687,  1.33671394,  0.85832554, -1.08515608,
#        -0.15724584,  0.509581  ,  1.64751056,  1.77692988,  0.46094041,
#        -1.77155442,  0.40784135,  1.51895487,  0.12642124, -0.42648748,
#        -1.3938093 ,  0.05351222,  0.44029745,  0.30585416,  1.18723427,
#        -0.29324339,  0.34685842, -0.31036795,  0.98104339, -1.16225756,
#         0.51940859, -0.04594949,  1.14195576, -1.44112254, -0.34632976,
#        -1.57576713, -1.42970911, -1.44382995, -1.70834427, -0.60274017,
#        -0.89915367,  0.29150541, -0.24396169, -0.55011709, -1.34094679,
#         0.09109163, -1.96345192,  2.0309088 , -0.67620225, -0.10901408,
#        -1.88905748,  1.89676092, -0.12444594,  0.69421678,  1.41655051,
#         1.37121841,  1.02321344, -1.02324831,  0.30429327, -1.65037983,
#         0.29206171, -1.64519611])

# %% [markdown]
# # LINEAR REGRESSION

# %%
reg = LinearRegression()
reg.fit(x_train,y_train)
y_pred = reg.predict(x_test)
rms = sqrt(mean_squared_error(y_test, y_pred))
rms
# Out:
# 2.4352942225887078

# %% [markdown]
# # RANDOM FOREST REGRESSOR

# %%
RFR = RandomForestRegressor()
rfr.fit(x_train,y_train)
y_pred=rfr.predict(x_test)
rms = sqrt(mean_squared_error(y_test, y_pred))
rms
# Out:
# 2.3974057517536513
